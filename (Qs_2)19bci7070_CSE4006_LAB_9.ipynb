# %% [markdown]
# # Name : Souri Yaswanth Krishna
# # Reg.No : 19bci7070
# # Course : CSE4006 LAB-9 Qs-2
# # Deepfake using pytorch here we are using to videos.

# %%
# !git clone https://github.com/IanSullivan/DeepFakeTorch.git
# Out:
# Cloning into 'DeepFakeTorch'...
# remote: Enumerating objects: 109, done.
# remote: Total 109 (delta 0), reused 0 (delta 0), pack-reused 109
# Receiving objects: 100% (109/109), 7.62 MiB | 3.38 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
# !git clone https://github.com/italojs/facial-landmarks-recognition.git
# Out:
# Cloning into 'facial-landmarks-recognition'...
# remote: Enumerating objects: 8, done.
# remote: Total 8 (delta 0), reused 0 (delta 0), pack-reused 8
# Unpacking objects: 100% (8/8), done.

# %%
cd /content/DeepFakeTorch
# Out:
# /content/DeepFakeTorch

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 49.4 MB 58 kB/s
# ERROR: Could not find a version that satisfies the requirement torchvision==0.4.2+cu92 (from versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3, 0.3.0, 0.4.0, 0.4.1, 0.4.2, 0.5.0, 0.6.0, 0.6.1, 0.7.0, 0.8.0, 0.8.1, 0.8.2, 0.9.0, 0.9.1, 0.10.0, 0.10.1, 0.11.0, 0.11.1)
# ERROR: No matching distribution found for torchvision==0.4.2+cu92

# %%
# !pip install opencv-python

# %%
# !pip install cmake

# %%
# !pip install dlib

# %%
# !pip install facenet_pytorch
# Out:
# ...
#      |████████████████████████████████| 1.9 MB 12.3 MB/s
# ...

# %%
# !pip install PyYAML==5.3.1
# Out:
# ...
#      |████████████████████████████████| 269 kB 13.3 MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44635 sha256=3403c049d49b81e3c831f60306bb98876a78ca0f6a3bc327ca67b449ee2a5c51
#   Stored in directory: /root/.cache/pip/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
# Successfully built PyYAML
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/DeepFakeTorch/00.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/DeepFakeTorch/04.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
# !python face_detect.py -video_src 00.mp4 -out_name a
# Out:
# Running on device: cuda:0
# Tracking frame: 265

# %%
# !python face_detect.py -video_src 04.mp4 -out_name b
# Out:
# Running on device: cuda:0
# Tracking frame: 211

# %%
# !python train.py -face_a_dir a -face_b_dir b -n_steps 100000
# Out:
# loading data...
# training for 100000 steps
# Epoch[1/100000] Loss A:-0.1274157464504242, Loss B:-0.15498140454292297
# Epoch[1001/100000] Loss A:-0.5814377069473267, Loss B:-0.8186859488487244
# Epoch[2001/100000] Loss A:-0.714849591255188, Loss B:-0.5960193276405334
# Epoch[3001/100000] Loss A:-0.7065898776054382, Loss B:-0.7811117172241211
# Epoch[4001/100000] Loss A:-0.7338274717330933, Loss B:-0.8486827611923218
# Epoch[5001/100000] Loss A:-0.7036963701248169, Loss B:-0.8026701807975769
# Epoch[6001/100000] Loss A:-0.7005144953727722, Loss B:-0.8495936393737793
# Epoch[7001/100000] Loss A:-0.7718164324760437, Loss B:-0.8789907693862915
# Epoch[8001/100000] Loss A:-0.8178831338882446, Loss B:-0.8358469009399414
# Epoch[9001/100000] Loss A:-0.7874482870101929, Loss B:-0.8733265399932861
# Epoch[10001/100000] Loss A:-0.8254780769348145, Loss B:-0.7846676707267761
# Epoch[11001/100000] Loss A:-0.7856144905090332, Loss B:-0.8654873371124268
# ...

# %%
# !python video_writer.py -original_video 04.mp4 -model_location saved_models/model.pt -out_name myswappedvideo -decoder a
# Out:
# Running on device: cuda:0
# Tracking frame: 1'list' object has no attribute 'tolist'
# Tracking frame: 6'list' object has no attribute 'tolist'
# Tracking frame: 9OpenCV(4.1.2) /io/opencv/modules/imgproc/src/imgwarp.cpp:2594: error: (-215:Assertion failed) src.cols > 0 && src.rows > 0 in function 'warpAffine'
#
# Tracking frame: 11'list' object has no attribute 'tolist'
# Tracking frame: 13'list' object has no attribute 'tolist'
# Tracking frame: 14OpenCV(4.1.2) /io/opencv/modules/imgproc/src/imgwarp.cpp:2594: error: (-215:Assertion failed) src.cols > 0 && src.rows > 0 in function 'warpAffine'
#
# Tracking frame: 16'list' object has no attribute 'tolist'
# Tracking frame: 17'list' object has no attribute 'tolist'
# Tracking frame: 18'list' object has no attribute 'tolist'
# Tracking frame: 19OpenCV(4.1.2) /io/opencv/modules/imgproc/src/imgwarp.cpp:2594: error: (-215:Assertion failed) src.cols > 0 && src.rows > 0 in function 'warpAffine'
#
# ...
